# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
# !yolo task=detect mode=train model=yolov8x.pt data="C:/Users/Windows/Documents/Basketball Detection/Basketball-Players-17/Basketball-Players-17/data.yaml"  epochs=100 imgsz=640 batch=16 project="runs/detect" name="yolov8n_basketball_players_17"
# Out:
# ^C
