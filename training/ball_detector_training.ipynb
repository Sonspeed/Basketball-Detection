# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# %%
# !yolo task= detect mode=train model=yolov5l6u.pt data="C:/Users/Windows/Documents/Basketball Detection/Basketball-Players-17/Basketball-Players-17/data.yaml" epochs=250 imgsz=640 batch=16 project="runs/detect" name="yolov5u_basketball_players_17"
